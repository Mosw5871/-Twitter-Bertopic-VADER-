# %% [markdown]
# # 数据导入

# %%
import pandas as pd
import nltk
import re

# %%
data_path = '/Volumes/时伟SSD512G/China-Central_Asia_Summit.csv'
df = pd.read_csv(data_path, encoding='utf8')

# %%
df.head()
# Out:
#    author_username in_reply_to_username retweeted_username quoted_username
# 0    thehousejapan                  NaN    yasminalombaert             NaN  \
# 1     jamilsiddiq3                  NaN         ChinaDaily             NaN
# 2     MyronGainez_                  NaN    Gerashchenko_en             NaN
# 3  dragonfire55555                  NaN    yasminalombaert             NaN
# 4         SokoVera                  NaN    Gerashchenko_en             NaN
#
#         date           time
# 0  2023/5/20  23:59:00.000Z  \
# 1  2023/5/20  23:58:45.000Z
# 2  2023/5/20  23:58:24.000Z
# 3  2023/5/20  23:58:03.000Z
# 4  2023/5/20  23:57:32.000Z
#
#                                                 text
# 0  A real bad weekend for pariah Putin.\n\nThe Sa...  \
# 1  Chinese State Councilor and Foreign Minister Q...
# 2  Congratulations to the great geopolitical stra...
# 3  A real bad weekend for pariah Putin.\n\nThe Sa...
# 4  Congratulations to the great geopolitical stra...
#
#    public_metrics.impression_count  public_metrics.reply_count
# 0                            78144                         110  \
# 1                             9288                          12
# 2                          1504896                         583
# 3                            78144                         110
# 4                          1504896                         583
#
#    public_metrics.retweet_count  public_metrics.quote_count
# 0                           468                          31  \
# 1                            40                           2
# 2                          2853                         226
# 3                           468                          31
# 4                          2853                         226
#
#    public_metrics.like_count         author.created_at
# 0                       2183  2016-03-11T05:51:16.000Z  \
# 1                        133  2014-04-23T17:13:59.000Z
# 2                      15819  2021-10-06T06:44:53.000Z
# 3                       2183  2011-01-27T02:52:30.000Z
# 4                      15819  2020-01-22T20:08:09.000Z
#
#   author.public_metrics.followers_count author.public_metrics.following_count
# 0                                    68                                  1110  \
# 1                                  1347                                  4985
# 2                                   284                                   135
# 3                                   822                                   261
# 4                                    12                                   108
#
#   author.public_metrics.tweet_count author.verified
# 0                             18221           FALSE
# 1                             54243           FALSE
# 2                              5821           FALSE
# 3                            239212           FALSE
# 4                              2867           FALSE

# %% [markdown]
# # 数据非常多，先提取需要的列

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16350 entries, 0 to 16349
# Data columns (total 17 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   author_username                        16350 non-null  object
#  1   in_reply_to_username                   173 non-null    object
#  2   retweeted_username                     13437 non-null  object
#  3   quoted_username                        328 non-null    object
#  4   date                                   16350 non-null  object
#  5   time                                   16350 non-null  object
#  6   text                                   16350 non-null  object
#  7   public_metrics.impression_count        16350 non-null  int64
#  8   public_metrics.reply_count             16350 non-null  int64
#  9   public_metrics.retweet_count           16350 non-null  int64
#  10  public_metrics.quote_count             16350 non-null  int64
#  11  public_metrics.like_count              16350 non-null  int64
#  12  author.created_at                      16350 non-null  object
#  13  author.public_metrics.followers_count  16280 non-null  object
#  14  author.public_metrics.following_count  16298 non-null  object
#  15  author.public_metrics.tweet_count      16269 non-null  object
#  16  author.verified                        15944 non-null  object
# dtypes: int64(5), object(12)
# memory usage: 2.1+ MB

# %% [markdown]
# # 可以开始数据预处理了

# %%
df["text"] = df["text"].str.lower()  # 统一为小写字母

# %%
# 导入nltk的分词工具word_tokenize和nltk的停用词表stopwords，需要自行下载哦
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

stopwords_list = stopwords.words("english")

# %%
# 定义一个函数，处理Twitter文本中的特殊符号：@xxx、&xxx、网址、多余的空格，最后只保留数字和字母
def clean_specialtext(tweet):
    tweet = re.sub(r"@([^\s:]+)", " ", tweet)  # 去除@提及内容
    tweet = re.sub(r"&([^\s:]+)", " ", tweet)  # 去除&及之后的内容
    tweet = re.sub(r"[a-zA-z]+://[^\s]*", " ", tweet)  # 去除网址
    tweet = re.sub(r"[^0-9A-Za-z]", " ", tweet)  # 仅保留数字及字母
    tweet = re.sub(r"(^\s*)|(\s*$)", "", tweet)  # 去除字符串前后空格
    # tweet = re.sub(r'[^0-9A-Za-z]', ' ', tweet)
    return tweet

# %%
df["text"] = df["text"].apply(lambda x: clean_specialtext(x))

# %%
#导入nltk的词性标注工具pos_tag、词性属性工具wordnet和词形还原工具WordNetLemmatizer
from nltk.stem import WordNetLemmatizer
from nltk.tag import pos_tag
from nltk.corpus import wordnet
lemmatizer = WordNetLemmatizer()

# %%
# 这一步是为了更精确词形还原，对词性进行标注，精确的词性对词形还原很有必要
# 参考https://stackoverflow.com/questions/61982023/using-wordnetlemmatizer-lemmatize-with-pos-tags-throws-keyerror
def get_wordnet_pos(treebank_tag):
    if treebank_tag.startswith("J"):
        return wordnet.ADJ
    elif treebank_tag.startswith("V"):
        return wordnet.VERB
    elif treebank_tag.startswith("N"):
        return wordnet.NOUN
    elif treebank_tag.startswith("R"):
        return wordnet.ADV
    else:
        return None

# %%
# 定义去除停用词和词形还原函数，每一步都是有顺序的，不能乱
def clean_stopwords_Lemmatization(tweet):
    tweet = word_tokenize(tweet)
    # print(tweet)
    # print("*"*100)
    tweet = [word for word in tweet if word not in stopwords_list]  # 去除停用词
    tweet = pos_tag(tweet)  # 词性标注
    # 词性标注好之后，列表里变成了（词，词性）的元组形式，word[0]是词的位置，对word[0]进行词形还原，依据是上面的函数和word[1]
    tweet = [
        lemmatizer.lemmatize(word[0], pos=get_wordnet_pos(word[1]))
        if get_wordnet_pos(word[1])
        else word[0]
        for word in tweet
    ]
    tweet = [word for word in tweet if len(word) > 2]  # 丢弃长度小于等于2的字符串
    tweet = " ".join(tweet)  # 将tweet列表中的字符串重新拼接起来，用空格分隔
    # print(tweet)
    # print("#"*100)
    return tweet

# %%
df['text'] = df['text'].apply(lambda x: clean_stopwords_Lemmatization(x))

# %%
df.head()
# Out:
#    author_username in_reply_to_username retweeted_username quoted_username
# 0    thehousejapan                  NaN    yasminalombaert             NaN  \
# 1     jamilsiddiq3                  NaN         ChinaDaily             NaN
# 2     MyronGainez_                  NaN    Gerashchenko_en             NaN
# 3  dragonfire55555                  NaN    yasminalombaert             NaN
# 4         SokoVera                  NaN    Gerashchenko_en             NaN
#
#         date           time
# 0  2023/5/20  23:59:00.000Z  \
# 1  2023/5/20  23:58:45.000Z
# 2  2023/5/20  23:58:24.000Z
# 3  2023/5/20  23:58:03.000Z
# 4  2023/5/20  23:57:32.000Z
#
#                                                 text
# 0  real bad weekend pariah putin nthe saudi invit...  \
# 1  chinese state councilor foreign minister qin g...
# 2  congratulation great geopolitical strategist p...
# 3  real bad weekend pariah putin nthe saudi invit...
# 4  congratulation great geopolitical strategist p...
#
#    public_metrics.impression_count  public_metrics.reply_count
# 0                            78144                         110  \
# 1                             9288                          12
# 2                          1504896                         583
# 3                            78144                         110
# 4                          1504896                         583
#
#    public_metrics.retweet_count  public_metrics.quote_count
# 0                           468                          31  \
# 1                            40                           2
# 2                          2853                         226
# 3                           468                          31
# 4                          2853                         226
#
#    public_metrics.like_count         author.created_at
# 0                       2183  2016-03-11T05:51:16.000Z  \
# 1                        133  2014-04-23T17:13:59.000Z
# 2                      15819  2021-10-06T06:44:53.000Z
# 3                       2183  2011-01-27T02:52:30.000Z
# 4                      15819  2020-01-22T20:08:09.000Z
#
#   author.public_metrics.followers_count author.public_metrics.following_count
# 0                                    68                                  1110  \
# 1                                  1347                                  4985
# 2                                   284                                   135
# 3                                   822                                   261
# 4                                    12                                   108
#
#   author.public_metrics.tweet_count author.verified
# 0                             18221           FALSE
# 1                             54243           FALSE
# 2                              5821           FALSE
# 3                            239212           FALSE
# 4                              2867           FALSE

# %%
df.to_csv('/Volumes/时伟SSD512G/CCAS清洗完成.csv', encoding='utf8')
